# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install transformers[torch]

# %%
pip install nervaluate

# %%
pip install tensorrt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tensorrt: filename=tensorrt-8.6.1.post1-py2.py3-none-any.whl size=17283 sha256=68b0b00c5a4ffa4da8f53df8b6dc4741eef981b7f7f35a1641245bd364da9421
#   Stored in directory: /root/.cache/pip/wheels/f4/c8/0e/b79b08e45752491b9acfdbd69e8a609e8b2ed7640dda5a3e59
# Successfully built tensorrt
# ...

# %%
# !python "//content//drive//MyDrive//L-NER Project//code//main.py" \
--ds_train_path "//content//drive//MyDrive//L-NER Project//data//4D_final_data.json" \
--ds_valid_path "//content//drive//MyDrive//L-NER Project//data//NER_DEV_ALL.json" \
--output_folder "//content//drive//MyDrive//L-NER Project//output//" \
--batch 1 \
--num_epochs 5 \
--lr 1e-4 \
--weight_decay 0.01 \
--warmup_ratio 0.06
# Out:
# 2024-02-23 17:48:08.365627: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-23 17:48:08.365679: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-23 17:48:08.367421: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-23 17:48:09.565986: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-02-23 17:48:10 numexpr.utils INFO: NumExpr defaulting to 2 threads.
# MODEL:  dslim/bert-large-NER
# ...
